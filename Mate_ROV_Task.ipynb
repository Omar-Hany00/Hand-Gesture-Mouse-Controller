# %% [markdown]
# <a href="https://colab.research.google.com/github/Omar-Hany00/-Hand-Gesture-Mouse-Controller/blob/main/Mate_ROV_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ERROR: Operation cancelled by user
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 50.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 26.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...

# %%
from ultralytics import YOLO
import cv2 as cv
from google.colab.patches import cv2_imshow
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-4284008695.py in <cell line: 0>()
# ----> 1 from ultralytics import YOLO
#       2 import cv2 as cv
#       3 from google.colab.patches import cv2_imshow
#
# ModuleNotFoundError: No module named 'ultralytics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="DcFCKrcl8sztjO73JJVr")
project = rf.workspace("mate-rov-task").project("crabs-detection-5sini")
version = project.version(1)
dataset = version.download("yolov8")

# %%
model=YOLO("yolov8n.pt")
model.train(data="Crabs-detection-1/data.yaml", epochs=35)

# %%
model=YOLO("/content/runs/detect/train3/weights/best.pt")

# %%
# !ls  /content

# %%
from google.colab import files

uploaded=files.upload()

# %%
img='test1.jpg'

results=model.predict(img, conf=0.5)

for r in results:
    img_detected=r.plot()
    cv2_imshow(img_detected)

# %%
img='test2.jpg'

results=model.predict(img, conf=0.5)

for r in results:
    img_detected=r.plot()
    cv2_imshow(img_detected)

# %%
img='test3.jpg'

results=model.predict(img, conf=0.5)

for r in results:
    img_detected=r.plot()
    cv2_imshow(img_detected)

# %%
img='test4.jpg'

results=model.predict(img, conf=0.5)

for r in results:
    img_detected=r.plot()
    cv2_imshow(img_detected)

# %%
from google.colab import files

uploaded=files.upload()

# %%
img='Ocypodidae.jpg'

results=model.predict(img, conf=0.5, iou=0.8)

for r in results:
  img_detected=r.plot()
  count=len(r.boxes)
  cv.putText(img_detected,f"{str(count)} crabs",(100,50),cv.FONT_HERSHEY_SIMPLEX,2,(0,0,0),3)
  cv2_imshow(img_detected)

# %%
from google.colab import files

uploaded=files.upload()

# %%
img='g.jpg'

results=model.predict(img, conf=0.5, iou=0.8)

for r in results:
  img_detected=r.plot()
  count=len(r.boxes)
  cv.putText(img_detected,f"{str(count)} crabs",(100,50),cv.FONT_HERSHEY_SIMPLEX,2,(0,0,0),3)
  cv2_imshow(img_detected)
